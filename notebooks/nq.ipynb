# %%
import pandas as pd

dataset_path = '../datasets_/v1.0-simplified_nq-dev-all.jsonl/v1.0-simplified_nq-dev-all.jsonl'
df = pd.read_json(dataset_path, lines=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       2
#       3 dataset_path = '../datasets_/v1.0-simplified_nq-dev-all.jsonl/v1.0-simplified_nq-dev-all.jsonl'
# ----> 4 df = pd.read_json(dataset_path, lines=True)
#
# File D:\P_work\Rag-VKR\.venv\Lib\site-packages\pandas\io\json\_json.py:853, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     851     return json_reader
#     852 else:
# --> 853     return json_reader.read()
#
# File D:\P_work\Rag-VKR\.venv\Lib\site-packages\pandas\io\json\_json.py:989, in JsonReader.read(self)
#     987         obj = self._read_pyarrow()
#     988     elif self.engine == "ujson":
# ...

# %%
df = pd.read_json(dataset_path, lines=True, encoding='utf-8', nrows=1000)

# %%
df
# Out:
#                                            annotations  \
# 0    [{'annotation_id': 13591449469826568799, 'long...
# 1    [{'annotation_id': 9256543824648308180, 'long_...
# 2    [{'annotation_id': 647276088892962831, 'long_a...
# 3    [{'annotation_id': 2430977867500315580, 'long_...
# 4    [{'annotation_id': 9697565976974065308, 'long_...
# ..                                                 ...
# 995  [{'annotation_id': 9850947005047531828, 'long_...
# 996  [{'annotation_id': 14443401039595128465, 'long...
# 997  [{'annotation_id': 13936736338887547733, 'long...
# 998  [{'annotation_id': 6001080811847477710, 'long_...
# 999  [{'annotation_id': 3767820468905660496, 'long_...
#
#                                          document_html  \
# 0    <!DOCTYPE html>\n<HTML class="client-js ve-not...
# 1    <!DOCTYPE html>\n<HTML class="client-js ve-not...
# 2    <!DOCTYPE html>\n<HTML class="client-js ve-not...
# 3    <!DOCTYPE html>\n<HTML class="client-js ve-not...
# ...

# %%
df.columns
# Out:
# Index(['annotations', 'document_html', 'document_title', 'document_tokens',
#        'document_url', 'example_id', 'long_answer_candidates', 'question_text',
#        'question_tokens'],
#       dtype='str')

# %%
df.iloc[0]
# Out:
# annotations               [{'annotation_id': 13591449469826568799, 'long...
# document_html             <!DOCTYPE html>\n<HTML class="client-js ve-not...
# document_title                                               Therefore sign
# document_tokens           [{'end_byte': 101, 'html_token': False, 'start...
# document_url              https://en.wikipedia.org//w/index.php?title=Th...
# example_id                                              6915606477668963399
# long_answer_candidates    [{'end_byte': 66428, 'end_token': 808, 'start_...
# question_text                               what do the 3 dots mean in math
# question_tokens                    [what, do, the, 3, dots, mean, in, math]
# Name: 0, dtype: object

# %%
df["long_answer_candidates"].iloc[0]
# Out:
# [{'end_byte': 66428,
#   'end_token': 808,
#   'start_byte': 41427,
#   'start_token': 14,
#   'top_level': True},
#  {'end_byte': 41683,
#   'end_token': 20,
#   'start_byte': 41505,
#   'start_token': 15,
#   'top_level': False},
#  {'end_byte': 41872,
#   'end_token': 26,
#   'start_byte': 41684,
#   'start_token': 20,
#   'top_level': False},
#  {'end_byte': 46585,
#   'end_token': 197,
#   'start_byte': 41873,
#   'start_token': 26,
#   'top_level': False},
#  {'end_byte': 46573,
#   'end_token': 195,
#   'start_byte': 41937,
#   'start_token': 28,
#   'top_level': False},
#  {'end_byte': 42207,
#   'end_token': 34,
#   'start_byte': 42050,
#   'start_token': 29,
#   'top_level': False},
#  {'end_byte': 42490,
#   'end_token': 43,
#   'start_byte': 42208,
#   'start_token': 34,
#   'top_level': False},
#  {'end_byte': 42841,
#   'end_token': 58,
#   'start_byte': 42491,
#   'start_token': 43,
#   'top_level': False},
#  {'end_byte': 43120,
#   'end_token': 66,
# ...
